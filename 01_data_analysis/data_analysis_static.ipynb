# %% [markdown]
# # Data Analysis

# %% [markdown]
# In this section, we conduct an analysis of the data required for our study and conclude by constructing the dataset that will be used in the following steps.

# %%
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
from data_analysis_utils import determine_active_unit, determine_percentage_active_units_by_area

# %%
df = pd.read_parquet('../ourdata/static_dataset_session_757216464.parquet')
baseline = pd.read_parquet('../ourdata/spontaneous_dataset_session_757216464.parquet')
baseline.drop(columns=['stimulus_condition_id','stimulus_presentation_count'], inplace=True)

# %% [markdown]
# The dataset we are working with includes the following elements:
#
# - **'stimulus_presentation_id'**: The ID of the stimulus presentation.
# - **'unit_id'**: The ID of the neuron.
# - **'spatial_frequency'**: How much the stimulus is structured.
# - **'orientation'**: The angle at which the stimulus is oriented.
# - **'spikes_per_second'**: The number of spikes per second recorded from the neuron in response to the stimulus.
# - **'area'**: The area of the brain where the neuron is located.

# %%
df
# Out:
#          stimulus_presentation_id    unit_id    stimulus_name  \
# index
# 0                           49434  951797083  static_gratings
# 1                           49434  951797141  static_gratings
# 2                           49434  951797185  static_gratings
# 3                           49434  951797253  static_gratings
# 4                           49434  951797285  static_gratings
# ...                           ...        ...              ...
# 3250866                     70389  951820289  static_gratings
# 3250867                     70389  951820298  static_gratings
# 3250868                     70389  951820332  static_gratings
# 3250869                     70389  951820363  static_gratings
# 3250870                     70389  951820445  static_gratings
#
#          spatial_frequency  orientation  spikes_per_second   area
# index
# 0                     0.32          0.0          43.964810    MGm
# 1                     0.32          0.0          43.964810    MGm
# 2                     0.32          0.0          19.984004    MGm
# 3                     0.32          0.0          23.980805    MGm
# 4                     0.32          0.0           7.993602    MGm
# ...                    ...          ...                ...    ...
# 3250866               0.04        150.0           7.993529    CA1
# 3250867               0.04        150.0          27.977350    CA1
# 3250868               0.04        150.0           3.996764  VISal
# 3250869               0.04        150.0           7.993529  VISal
# 3250870               0.04        150.0           7.993529     LP
#
# [3150075 rows x 7 columns]

# %% [markdown]
# We also imported another dataset that we are going to use to determine if a neuron is active or no.
#
# This dataset contains the following elements:
# - **'unit_id'**: The ID of the neuron.
# - **'spike_mean'**: The mean of the spikes per seconds for each unit
# - **'spike_std'**: The standard deviation of the spikes per seconds for each unit
# - **'spike_sem'**: The standard deviation over the square root of the number of samples

# %%
baseline
# Out:
#        unit_id  spike_mean  spike_std  spike_sem
# 0    951797083   20.610074   8.005496   2.067010
# 1    951797141    9.985374   3.724447   0.961648
# 2    951797185   15.454206   4.546035   1.173781
# 3    951797219    0.399453   0.280883   0.072524
# 4    951797253   10.662142   5.942843   1.534435
# ..         ...         ...        ...        ...
# 954  951820372    0.042913   0.071110   0.018361
# 955  951820428    9.196453   7.838665   2.023935
# 956  951820436   12.740605   2.787762   0.719797
# 957  951820445   11.454786   4.314321   1.113953
# 958  951820466    0.448325   0.339435   0.087642
#
# [959 rows x 4 columns]

# %%
baseline_renamed = baseline.rename(columns={
    'spike_mean': 'spike_mean_baseline',
    'spike_std': 'spike_std_baseline'
})

baseline_cols = ['unit_id', 'spike_mean_baseline', 'spike_std_baseline']
baseline_reduced = baseline_renamed[baseline_cols]

df = df.merge(baseline_reduced, on='unit_id', how='left')

df
# Out:
#          stimulus_presentation_id    unit_id    stimulus_name  \
# 0                           49434  951797083  static_gratings
# 1                           49434  951797141  static_gratings
# 2                           49434  951797185  static_gratings
# 3                           49434  951797253  static_gratings
# 4                           49434  951797285  static_gratings
# ...                           ...        ...              ...
# 3150070                     70389  951820289  static_gratings
# 3150071                     70389  951820298  static_gratings
# 3150072                     70389  951820332  static_gratings
# 3150073                     70389  951820363  static_gratings
# 3150074                     70389  951820445  static_gratings
#
#          spatial_frequency  orientation  spikes_per_second   area  \
# 0                     0.32          0.0          43.964810    MGm
# 1                     0.32          0.0          43.964810    MGm
# 2                     0.32          0.0          19.984004    MGm
# 3                     0.32          0.0          23.980805    MGm
# 4                     0.32          0.0           7.993602    MGm
# ...                    ...          ...                ...    ...
# 3150070               0.04        150.0           7.993529    CA1
# 3150071               0.04        150.0          27.977350    CA1
# 3150072               0.04        150.0           3.996764  VISal
# 3150073               0.04        150.0           7.993529  VISal
# 3150074               0.04        150.0           7.993529     LP
#
#          spike_mean_baseline  spike_std_baseline
# 0                  20.610074            8.005496
# 1                   9.985374            3.724447
# 2                  15.454206            4.546035
# 3                  10.662142            5.942843
# 4                   0.720306            0.492562
# ...                      ...                 ...
# 3150070             7.274855            2.230240
# 3150071             6.219202            2.868306
# 3150072             1.577880            0.763692
# 3150073             0.692921            0.480915
# 3150074            11.454786            4.314321
#
# [3150075 rows x 9 columns]

# %% [markdown]
# # Creation of the new dataset

# %% [markdown]
# We create a new dataset that we will use at various points in our analysis and in the upcoming sessions. This dataset is grouped by area and stimulus ID, and for each combination of these two variables, it contains the proportion of active units, the temporal frequency, and the orientation.

# %%
df2 = determine_active_unit(df, z_threshold=2)
# Out:
# Unit activity determined with z-threshold: 2

# %%
df2
# Out:
#          stimulus_presentation_id    unit_id    stimulus_name  \
# 0                           49434  951797083  static_gratings
# 1                           49434  951797141  static_gratings
# 2                           49434  951797185  static_gratings
# 3                           49434  951797253  static_gratings
# 4                           49434  951797285  static_gratings
# ...                           ...        ...              ...
# 3150070                     70389  951820289  static_gratings
# 3150071                     70389  951820298  static_gratings
# 3150072                     70389  951820332  static_gratings
# 3150073                     70389  951820363  static_gratings
# 3150074                     70389  951820445  static_gratings
#
#          spatial_frequency  orientation  spikes_per_second   area  \
# 0                     0.32          0.0          43.964810    MGm
# 1                     0.32          0.0          43.964810    MGm
# 2                     0.32          0.0          19.984004    MGm
# 3                     0.32          0.0          23.980805    MGm
# 4                     0.32          0.0           7.993602    MGm
# ...                    ...          ...                ...    ...
# 3150070               0.04        150.0           7.993529    CA1
# 3150071               0.04        150.0          27.977350    CA1
# 3150072               0.04        150.0           3.996764  VISal
# 3150073               0.04        150.0           7.993529  VISal
# 3150074               0.04        150.0           7.993529     LP
#
#          spike_mean_baseline  spike_std_baseline  z_score_to_baseline  active
# 0                  20.610074            8.005496             2.917338       1
# 1                   9.985374            3.724447             9.123351       1
# 2                  15.454206            4.546035             0.996428       0
# 3                  10.662142            5.942843             2.241127       1
# 4                   0.720306            0.492562            14.766260       1
# ...                      ...                 ...                  ...     ...
# 3150070             7.274855            2.230240             0.322241       0
# 3150071             6.219202            2.868306             7.585713       1
# 3150072             1.577880            0.763692             3.167357       1
# 3150073             0.692921            0.480915            15.180674       1
# 3150074            11.454786            4.314321            -0.802272       0
#
# [3150075 rows x 11 columns]

# %%
df3 = determine_percentage_active_units_by_area(df2)

# %%
df3
# Out:
#          area  stimulus_presentation_id  proportion_active_units  \
# 0         APN                     49434                 0.363636
# 1         APN                     49435                 0.264706
# 2         APN                     49436                 0.323529
# 3         APN                     49437                 0.366667
# 4         APN                     49438                 0.371429
# ...       ...                       ...                      ...
# 122948  VISrl                     70385                 0.555556
# 122949  VISrl                     70386                 0.181818
# 122950  VISrl                     70387                 0.181818
# 122951  VISrl                     70388                 0.000000
# 122952  VISrl                     70389                 0.315789
#
#         spatial_frequency  orientation
# 0                    0.32          0.0
# 1                    0.32          0.0
# 2                    0.04         90.0
# 3                    0.16        120.0
# 4                    0.08         90.0
# ...                   ...          ...
# 122948               0.08          0.0
# 122949               0.32         60.0
# 122950               0.16          0.0
# 122951               0.04        150.0
# 122952               0.04        150.0
#
# [122953 rows x 5 columns]

# %%
df3.to_parquet('../ourdata/df_static_session_757216464.parquet', index=False)

# %% [markdown]
# ## Data analysis

# %% [markdown]
# We begin our analysis by checking for duplicates and NaN values, verifying that the data is of the correct type for our analysis (i.e., numerical values for all variables except 'stimulus_name' and 'area'), and reviewing general information about the distribution of the variables.

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# We have no duplicates in our dataset.

# %%
print(df.isnull().sum())
# Out:
# stimulus_presentation_id    0
# unit_id                     0
# stimulus_name               0
# spatial_frequency           0
# orientation                 0
# spikes_per_second           0
# area                        0
# spike_mean_baseline         0
# spike_std_baseline          0
# dtype: int64

# %% [markdown]
# We have no Nan values in our dataset.

# %%
print(df.dtypes)
# Out:
# stimulus_presentation_id      int64
# unit_id                       int64
# stimulus_name                object
# spatial_frequency           float64
# orientation                 float64
# spikes_per_second           float64
# area                         object
# spike_mean_baseline         float64
# spike_std_baseline          float64
# dtype: object

# %% [markdown]
# All variables are of correct type.

# %%
print(df.describe())
# Out:
#        stimulus_presentation_id       unit_id  spatial_frequency  \
# count              3.150075e+06  3.150075e+06       3.150075e+06
# mean               5.852932e+04  9.518093e+08       1.235491e-01
# std                8.148448e+03  7.655798e+03       1.089519e-01
# min                4.943400e+04  9.517971e+08       2.000000e-02
# 25%                5.072900e+04  9.518016e+08       4.000000e-02
# 50%                5.605700e+04  9.518105e+08       8.000000e-02
# 75%                6.884800e+04  9.518168e+08       1.600000e-01
# max                7.038900e+04  9.518205e+08       3.200000e-01
#
#         orientation  spikes_per_second  spike_mean_baseline  \
# count  3.150075e+06       3.150075e+06         3.150075e+06
# mean   7.497039e+01       1.474008e+01         1.073203e+01
# std    5.127796e+01       1.332359e+01         9.653908e+00
# min    0.000000e+00       3.996402e+00         3.646713e-02
# 25%    3.000000e+01       3.996764e+00         4.562801e+00
# 50%    6.000000e+01       1.198968e+01         8.728963e+00
# 75%    1.200000e+02       1.998301e+01         1.366888e+01
# max    1.500000e+02       3.237312e+02         6.899552e+01
#
#        spike_std_baseline
# count        3.150075e+06
# mean         4.358806e+00
# std          2.993404e+00
# min          4.257275e-02
# 25%          2.391897e+00
# 50%          3.793499e+00
# 75%          5.495152e+00
# max          2.071364e+01

# %% [markdown]
# We are focusing on the static_gratings as stimuli.
# Each static_grating has two main characteristics which are orientation and spatial_frequency.
#
# Let's look at the possible values these features can take.

# %%
print("STATIC GRATINGS")
print('Possible values:')
print(' - Orientation: ', df['orientation'].unique())
print(' - Spatial_frequency: ', df['spatial_frequency'].unique())
# Out:
# STATIC GRATINGS
# Possible values:
#  - Orientation:  [  0.  90. 120.  60. 150.  30.]
#  - Spatial_frequency:  [0.32 0.04 0.16 0.08 0.02]

# %% [markdown]
# Let's now see how many datapoints we have of each values of spatial frequency, orientation and area.

# %%
sns.countplot(x='spatial_frequency', data=df)
# Out:
# <Axes: xlabel='spatial_frequency', ylabel='count'>

# %%
sns.countplot(x='orientation', data=df)
# Out:
# <Axes: xlabel='orientation', ylabel='count'>

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='area', data=df)
plt.show()

# %% [markdown]
# As we can see, we have almost an equal number of counts for temporal frequency and orientation, while for the area, some values appear more frequently than others.

# %% [markdown]
# ## Normalization

# %% [markdown]
# Let's now look at the distribution of the spikes per second.

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.histplot(df['spikes_per_second'], kde=True, bins=30, ax=ax)

ax.set_title("Spikes per second")
ax.set_xlabel("Spikes per Second")
ax.set_ylabel("Frequency")
ax.set_xlim(left=0, right=80)  

plt.show()

# %% [markdown]
# We see that the distribution is highly skewed to the left. This means that we have lots of neurons which have a few number of spikes per second.
#
# In order to reduce this we try to apply log tranformation, square root transformation and box-cox transformation.

# %%
df["log_spikes"] = np.log1p(df["spikes_per_second"])  
sns.histplot(df["log_spikes"], kde=True, bins=30)
plt.title("Log-Transformed Spike per Second Distribution")
plt.xlabel("Log(Spikes per Second)")
plt.ylabel("Frequency")
plt.show()

# %%
df["sqrt_spikes"] = np.sqrt(df["spikes_per_second"])
sns.histplot(df["sqrt_spikes"], kde=True, bins=30)
plt.title("Sqrt-Transformed Spike per Second Distribution")
plt.xlabel("Sqrt(Spikes per Second)")
plt.ylabel("Frequency")
plt.show()

# %%
df["boxcox_spikes"], _ = stats.boxcox(df["spikes_per_second"])
sns.histplot(df["boxcox_spikes"], kde=True, bins=30)
plt.title("Box-Cox Transformed Spike per Second Distribution")
plt.xlabel("Box-Cox(Spikes per Second)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# No tranformation works correctly to make the data assume a normal distribution.

# %% [markdown]
# Let's now look better at the structure of the data using a boxplot.

# %%
sns.boxplot(y=df["spikes_per_second"])
plt.title("Boxplot of Spikes per Second")
plt.show()

# %% [markdown]
# As we can see we have a big concentration of points in the range 0-20 and lots of outliers with larger values.

# %% [markdown]
# ## Correlation

# %% [markdown]
# We now look at the correlation between spatial frequency and spikes per second and between orientation and spikes per second.

# %%
correlation_matrix = df[['spatial_frequency', 'spikes_per_second']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
correlation_matrix = df[['orientation', 'spikes_per_second']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# As we can see we don't have direct linear relationship between the orientation and the spikes per second and between the spatial frequency and the spikes per second. This is consistent with our hypothesis, which is that a certain combination of orientation and spatial frequency causes different effects in each part of the brain.

# %% [markdown]
# ## Analysis of areas structure

# %% [markdown]
# We now focus on analysis the areas we will consider. What we want to see in particular is if each neuron of the area has similar reaction to a certain
# stimulus.
#
# We do so by picking four areas and plot the values of spike per second for each neuron in the case of four different stimulus.

# %%
random_areas = ['LP', 'CA1', 'VISp', 'PO']

colors = plt.cm.get_cmap('tab10', 4)  

for i, area in enumerate(random_areas):
    stimuli_in_area = df[df['area'] == area]['stimulus_presentation_id'].unique()
    random_stimuli = [55598, 55885, 56798, 55447]
    area_data = df[(df['area'] == area) & (df['stimulus_presentation_id'].isin(random_stimuli))]

    fig, axes = plt.subplots(1, 4, figsize=(20, 6))  
    
    for j, stimulus in enumerate(random_stimuli):
        stimulus_data = area_data[area_data['stimulus_presentation_id'] == stimulus]
       
        axes[j].scatter(range(len(stimulus_data)), stimulus_data['spikes_per_second'],
                        color=colors(j), label=f'Stimulus {stimulus}')
        
        axes[j].set_title(f'Stimulus {stimulus}')
        axes[j].set_xlabel('Unit (in line)')
        axes[j].set_ylabel('Spikes per Second')
        axes[j].grid(True)
        axes[j].legend()

    fig.suptitle(f'Spike Rates for Units in Area: {area}', fontsize=16)

    plt.tight_layout()

    plt.show()
# Out:
# /var/folders/l5/l2yq9xlj55l1p5qsn5c6n5wh0000gn/T/ipykernel_44461/359427858.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', 4)

# %% [markdown]
# As we can see the spikes per second of each neuron within the same area are very different.
#
# Our analysis will in fact be directed towards determing if an area is active or not. The way to determine this is set by us in the following way: if more than the 30% of the neurons in the area has the values of simulus_per_second larger than 10 then the area is considered active.

# %% [markdown]
# Now we want to verify something fundamental for our analysis: if different stimulus activate different areas of the brain.
#
# Let's consider four stimulus and see which areas are active in the four cases.

# %%
stimuli = [69454, 50921, 69225, 55868]

# %%
def classification_areas(stimuli,i):
    i = stimuli[i]
    for area in df3['area'].unique():
        value_series = df3[(df3['area'] == area) & (df3['stimulus_presentation_id'] == i)]['proportion_active_units']
    
        if not value_series.empty and value_series.item() >= 0.30:
            print(f"Area: {area} - active")
        else:
            print(f"Area: {area} - inactive")

# %%
classification_areas(stimuli,0)
# Out:
# Area: APN - active
# Area: CA1 - active
# Area: CA3 - active
# Area: DG - active
# Area: Eth - inactive
# Area: LGd - active
# Area: LGv - inactive
# Area: LP - active
# Area: MB - active
# Area: MGm - inactive
# Area: MRN - inactive
# Area: NOT - inactive
# Area: PO - inactive
# Area: ProS - active
# Area: SGN - active
# Area: SUB - inactive
# Area: TH - inactive
# Area: VIS - inactive
# Area: VISal - active
# Area: VISam - active
# Area: VISl - active
# Area: VISp - active
# Area: VISrl - active

# %%
classification_areas(stimuli,1)
# Out:
# Area: APN - inactive
# Area: CA1 - inactive
# Area: CA3 - active
# Area: DG - inactive
# Area: Eth - active
# Area: LGd - inactive
# Area: LGv - inactive
# Area: LP - active
# Area: MB - active
# Area: MGm - active
# Area: MRN - inactive
# Area: NOT - active
# Area: PO - inactive
# Area: ProS - inactive
# Area: SGN - inactive
# Area: SUB - inactive
# Area: TH - active
# Area: VIS - active
# Area: VISal - active
# Area: VISam - inactive
# Area: VISl - active
# Area: VISp - active
# Area: VISrl - active

# %%
classification_areas(stimuli,2)
# Out:
# Area: APN - inactive
# Area: CA1 - active
# Area: CA3 - active
# Area: DG - inactive
# Area: Eth - inactive
# Area: LGd - inactive
# Area: LGv - inactive
# Area: LP - inactive
# Area: MB - inactive
# Area: MGm - inactive
# Area: MRN - active
# Area: NOT - active
# Area: PO - inactive
# Area: ProS - inactive
# Area: SGN - active
# Area: SUB - inactive
# Area: TH - inactive
# Area: VIS - inactive
# Area: VISal - active
# Area: VISam - inactive
# Area: VISl - active
# Area: VISp - active
# Area: VISrl - active

# %%
classification_areas(stimuli,3)
# Out:
# Area: APN - inactive
# Area: CA1 - inactive
# Area: CA3 - active
# Area: DG - inactive
# Area: Eth - inactive
# Area: LGd - inactive
# Area: LGv - active
# Area: LP - inactive
# Area: MB - active
# Area: MGm - active
# Area: MRN - inactive
# Area: NOT - active
# Area: PO - active
# Area: ProS - inactive
# Area: SGN - active
# Area: SUB - inactive
# Area: TH - inactive
# Area: VIS - inactive
# Area: VISal - active
# Area: VISam - active
# Area: VISl - inactive
# Area: VISp - inactive
# Area: VISrl - active

# %% [markdown]
# As we can see in the four cases we have four different situations.
#
# In particular, let's see the case of the area LP for the four stimuli.

# %%
active_color = 'darkgreen'
inactive_color = 'lightgreen'

fig, axes = plt.subplots(2, 2, figsize=(20, 12))
axes = axes.flatten()

for j, stimulus in enumerate(stimuli):
  
    active = df2[(df2['area'] == 'LP') & 
                 (df2['stimulus_presentation_id'] == stimulus) & 
                 (df2['active'] == 1)]
    
    inactive = df2[(df2['area'] == 'LP') & 
                   (df2['stimulus_presentation_id'] == stimulus) & 
                   (df2['active'] == 0)]

    axes[j].scatter(range(len(active)), active['spikes_per_second'], 
                    color=active_color, label='Active Units')
    
    axes[j].scatter(range(len(inactive)), inactive['spikes_per_second'],
                    color=inactive_color, label='Inactive Units')
    
    axes[j].set_title(f'Stimulus {stimulus}')
    axes[j].set_xlabel('Units')
    axes[j].set_ylabel('Spikes per Second')
    axes[j].grid(True)
    axes[j].legend()

fig.suptitle('Spike Rates for Units in Area: LP', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see in the first two cases, where LP is defined as active, a large proportion of the neurons are considered active (dark green). In the second case, however, most of the neurons are inactive (light green), which makes sense since in these cases LP was judged to be inactive.
